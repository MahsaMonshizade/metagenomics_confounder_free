# %%
import os
import pandas as pd

# List of folders
folders = ['Results/FCNN_encoder_confounder_free_plots', 'Results/FCNN_plots', 'Results/MicroKPNN_encoder_confounder_free_plots', 'Results/MicroKPNN_plots', 'Results/Taxonomy_encoder_confounder_free_plots']

# Metrics to calculate
metrics = ['Train_Accuracy', 'Val_Accuracy', 'Test_Accuracy',
           'Train_F1', 'Val_F1', 'Test_F1',
           'Train_AUCPR', 'Val_AUCPR', 'Test_AUCPR',
           'Train_precision', 'Val_precision', 'Test_precision',
           'Train_recall', 'Val_recall', 'Test_recall']

# Initialize an empty list to store results
results = []

for folder in folders:
    # Path to the metrics_summary.csv file
    file_path = os.path.join(folder, 'metrics_summary.csv')
    
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Drop the last row if it's the 'Average' row
    df = df[:-1]
    
    # Calculate average and variance for each metric
    averages = df[metrics].mean()
    variances = df[metrics].var()
    
    # Combine the averages and variances into a single row
    summary = {metric: f"{averages[metric]:.4f} ± {variances[metric]:.4f}" for metric in metrics}
    summary['Folder'] = folder
    
    # Append the summary to results
    results.append(summary)

# Convert the results to a DataFrame
summary_df = pd.DataFrame(results).set_index('Folder')

# Save the summary to a new CSV file
output_path = 'metrics_summary_table.csv'
summary_df.to_csv(output_path)

# Display the summary DataFrame
print(summary_df)
# Out:
#                                                   Train_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9982 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9528 ± 0.0009
# Results/MicroKPNN_plots                          0.9992 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.6148 ± 0.0015
#
#                                                     Val_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7081 ± 0.0009
# Results/FCNN_plots                               0.6775 ± 0.0004
# Results/MicroKPNN_encoder_confounder_free_plots  0.6977 ± 0.0025
# Results/MicroKPNN_plots                          0.6940 ± 0.0036
# Results/Taxonomy_encoder_confounder_free_plots   0.5716 ± 0.0011
#
#                                                    Test_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7530 ± 0.0001
# Results/FCNN_plots                               0.6755 ± 0.0015
# Results/MicroKPNN_encoder_confounder_free_plots  0.7318 ± 0.0002
# Results/MicroKPNN_plots                          0.7197 ± 0.0007
# Results/Taxonomy_encoder_confounder_free_plots   0.5432 ± 0.0015
#
#                                                         Train_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9982 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9502 ± 0.0011
# Results/MicroKPNN_plots                          0.9992 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.6504 ± 0.0003
#
#                                                           Val_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7003 ± 0.0016
# Results/FCNN_plots                               0.7558 ± 0.0012
# Results/MicroKPNN_encoder_confounder_free_plots  0.6743 ± 0.0044
# Results/MicroKPNN_plots                          0.7732 ± 0.0013
# Results/Taxonomy_encoder_confounder_free_plots   0.4580 ± 0.0811
#
#                                                          Test_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.6536 ± 0.0002
# Results/FCNN_plots                               0.5680 ± 0.0016
# Results/MicroKPNN_encoder_confounder_free_plots  0.6276 ± 0.0003
# Results/MicroKPNN_plots                          0.6127 ± 0.0007
# Results/Taxonomy_encoder_confounder_free_plots   0.3178 ± 0.0336
#
#                                                      Train_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       1.0000 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9973 ± 0.0000
# Results/MicroKPNN_plots                          1.0000 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.8501 ± 0.0001
#
#                                                        Val_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9052 ± 0.0006
# Results/FCNN_plots                               0.8952 ± 0.0002
# Results/MicroKPNN_encoder_confounder_free_plots  0.9038 ± 0.0004
# Results/MicroKPNN_plots                          0.8967 ± 0.0002
# Results/Taxonomy_encoder_confounder_free_plots   0.8353 ± 0.0013
#
#                                                       Test_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.6651 ± 0.0008
# Results/FCNN_plots                               0.6231 ± 0.0078
# Results/MicroKPNN_encoder_confounder_free_plots  0.6609 ± 0.0036
# Results/MicroKPNN_plots                          0.6804 ± 0.0036
# Results/Taxonomy_encoder_confounder_free_plots   0.3766 ± 0.0005
#
#                                                  Train_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       1.0000 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9995 ± 0.0000
# Results/MicroKPNN_plots                          1.0000 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.8344 ± 0.0014
#
#                                                    Val_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9139 ± 0.0008
# Results/FCNN_plots                               0.8547 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9146 ± 0.0014
# Results/MicroKPNN_plots                          0.8650 ± 0.0018
# Results/Taxonomy_encoder_confounder_free_plots   0.8851 ± 0.0112
#
#                                                   Test_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.5901 ± 0.0013
# Results/FCNN_plots                               0.4489 ± 0.0013
# Results/MicroKPNN_encoder_confounder_free_plots  0.5602 ± 0.0016
# Results/MicroKPNN_plots                          0.4750 ± 0.0004
# Results/Taxonomy_encoder_confounder_free_plots   0.4411 ± 0.0315
#
#                                                     Train_recall  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9965 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9071 ± 0.0036
# Results/MicroKPNN_plots                          0.9985 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.5348 ± 0.0013
#
#                                                       Val_recall  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.5697 ± 0.0030
# Results/FCNN_plots                               0.6788 ± 0.0029
# Results/MicroKPNN_encoder_confounder_free_plots  0.5374 ± 0.0060
# Results/MicroKPNN_plots                          0.7010 ± 0.0026
# Results/Taxonomy_encoder_confounder_free_plots   0.3717 ± 0.0726
#
#                                                      Test_recall
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7364 ± 0.0017
# Results/FCNN_plots                               0.7773 ± 0.0060
# Results/MicroKPNN_encoder_confounder_free_plots  0.7182 ± 0.0017
# Results/MicroKPNN_plots                          0.8636 ± 0.0023
# Results/Taxonomy_encoder_confounder_free_plots   0.4136 ± 0.1421
