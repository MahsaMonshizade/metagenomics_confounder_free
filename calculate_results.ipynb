# %%
import os
import pandas as pd

# List of folders
folders = ['Results/FCNN_encoder_confounder_free_plots', 'Results/FCNN_plots', 'Results/MicroKPNN_encoder_confounder_free_plots', 'Results/MicroKPNN_plots', 'Results/Taxonomy_encoder_confounder_free_plots']

# Metrics to calculate
metrics = ['Train_Accuracy', 'Val_Accuracy', 'Test_Accuracy',
           'Train_F1', 'Val_F1', 'Test_F1',
           'Train_AUCPR', 'Val_AUCPR', 'Test_AUCPR',
           'Train_precision', 'Val_precision', 'Test_precision',
           'Train_recall', 'Val_recall', 'Test_recall']

# Initialize an empty list to store results
results = []

for folder in folders:
    # Path to the metrics_summary.csv file
    file_path = os.path.join(folder, 'metrics_summary.csv')
    
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Drop the last row if it's the 'Average' row
    df = df[:-1]
    
    # Calculate average and variance for each metric
    averages = df[metrics].mean()
    variances = df[metrics].var()
    
    # Combine the averages and variances into a single row
    summary = {metric: f"{averages[metric]:.4f} ± {variances[metric]:.4f}" for metric in metrics}
    summary['Folder'] = folder
    
    # Append the summary to results
    results.append(summary)

# Convert the results to a DataFrame
summary_df = pd.DataFrame(results).set_index('Folder')

# Save the summary to a new CSV file
output_path = 'metrics_summary_table.csv'
summary_df.to_csv(output_path)

# Display the summary DataFrame
print(summary_df)
# Out:
#                                                   Train_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9827 ± 0.0009
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9891 ± 0.0000
# Results/MicroKPNN_plots                          0.9980 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.6287 ± 0.0012
#
#                                                     Val_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7172 ± 0.0016
# Results/FCNN_plots                               0.7090 ± 0.0003
# Results/MicroKPNN_encoder_confounder_free_plots  0.7272 ± 0.0009
# Results/MicroKPNN_plots                          0.6854 ± 0.0008
# Results/Taxonomy_encoder_confounder_free_plots   0.5907 ± 0.0034
#
#                                                    Test_Accuracy  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7280 ± 0.0004
# Results/FCNN_plots                               0.6601 ± 0.0015
# Results/MicroKPNN_encoder_confounder_free_plots  0.7500 ± 0.0002
# Results/MicroKPNN_plots                          0.7154 ± 0.0022
# Results/Taxonomy_encoder_confounder_free_plots   0.5104 ± 0.0025
#
#                                                         Train_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9827 ± 0.0008
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9890 ± 0.0000
# Results/MicroKPNN_plots                          0.9980 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.6378 ± 0.0023
#
#                                                           Val_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7183 ± 0.0017
# Results/FCNN_plots                               0.7906 ± 0.0001
# Results/MicroKPNN_encoder_confounder_free_plots  0.7477 ± 0.0007
# Results/MicroKPNN_plots                          0.7671 ± 0.0010
# Results/Taxonomy_encoder_confounder_free_plots   0.5672 ± 0.0210
#
#                                                          Test_F1  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.6235 ± 0.0005
# Results/FCNN_plots                               0.5584 ± 0.0012
# Results/MicroKPNN_encoder_confounder_free_plots  0.6466 ± 0.0002
# Results/MicroKPNN_plots                          0.6101 ± 0.0019
# Results/Taxonomy_encoder_confounder_free_plots   0.3759 ± 0.0063
#
#                                                      Train_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9986 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9999 ± 0.0000
# Results/MicroKPNN_plots                          1.0000 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.8598 ± 0.0006
#
#                                                        Val_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9168 ± 0.0014
# Results/FCNN_plots                               0.8853 ± 0.0001
# Results/MicroKPNN_encoder_confounder_free_plots  0.9085 ± 0.0005
# Results/MicroKPNN_plots                          0.8957 ± 0.0004
# Results/Taxonomy_encoder_confounder_free_plots   0.8309 ± 0.0040
#
#                                                       Test_AUCPR  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.6730 ± 0.0051
# Results/FCNN_plots                               0.5726 ± 0.0012
# Results/MicroKPNN_encoder_confounder_free_plots  0.6846 ± 0.0029
# Results/MicroKPNN_plots                          0.6828 ± 0.0034
# Results/Taxonomy_encoder_confounder_free_plots   0.3903 ± 0.0017
#
#                                                  Train_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9989 ± 0.0000
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  1.0000 ± 0.0000
# Results/MicroKPNN_plots                          1.0000 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.8531 ± 0.0020
#
#                                                    Val_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9169 ± 0.0020
# Results/FCNN_plots                               0.8698 ± 0.0003
# Results/MicroKPNN_encoder_confounder_free_plots  0.9089 ± 0.0007
# Results/MicroKPNN_plots                          0.8582 ± 0.0003
# Results/Taxonomy_encoder_confounder_free_plots   0.8329 ± 0.0025
#
#                                                   Test_precision  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.5428 ± 0.0027
# Results/FCNN_plots                               0.4220 ± 0.0011
# Results/MicroKPNN_encoder_confounder_free_plots  0.5473 ± 0.0001
# Results/MicroKPNN_plots                          0.4681 ± 0.0018
# Results/Taxonomy_encoder_confounder_free_plots   0.4163 ± 0.0664
#
#                                                     Train_recall  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.9682 ± 0.0027
# Results/FCNN_plots                               1.0000 ± 0.0000
# Results/MicroKPNN_encoder_confounder_free_plots  0.9783 ± 0.0000
# Results/MicroKPNN_plots                          0.9960 ± 0.0000
# Results/Taxonomy_encoder_confounder_free_plots   0.5131 ± 0.0043
#
#                                                       Val_recall  \
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.5939 ± 0.0038
# Results/FCNN_plots                               0.7253 ± 0.0007
# Results/MicroKPNN_encoder_confounder_free_plots  0.6364 ± 0.0015
# Results/MicroKPNN_plots                          0.6949 ± 0.0026
# Results/Taxonomy_encoder_confounder_free_plots   0.4485 ± 0.0233
#
#                                                      Test_recall
# Folder
# Results/FCNN_encoder_confounder_free_plots       0.7409 ± 0.0025
# Results/FCNN_plots                               0.8273 ± 0.0012
# Results/MicroKPNN_encoder_confounder_free_plots  0.7909 ± 0.0014
# Results/MicroKPNN_plots                          0.8773 ± 0.0012
# Results/Taxonomy_encoder_confounder_free_plots   0.5318 ± 0.0704
